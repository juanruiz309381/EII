# %% [markdown]
# **PUNTO 2: Clasificación de Datos adjuntados en el link:**

# %%
# ===============================
# PUNTO 2 - CLASIFICACIÓN DE DATOS
# ===============================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# 1. Cargar dataset desde el archivo descargado
df = pd.read_csv("Classification_Data.csv")  # cambia a la ruta real si lo guardas localmente
print(df.head())
print(df.info())

# 2. Preparar datos
X = df[["x", "y"]]   # columnas de entrada
y = df["label"]      # columna objetivo

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# 3. Definir el modelo optimizado
model = Sequential([
    Dense(64, activation='relu', input_shape=(2,)),   # capa de entrada (2 features: x, y)
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dropout(0.2),                                     # ayuda a evitar overfitting
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')                    # salida binaria (0/1)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# 4. Entrenar
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=32,
    verbose=1
)

# 5. Evaluar
loss, acc = model.evaluate(X_test, y_test)
print(f"Accuracy en test: {acc*100:.2f}%")

# 6. Predicciones y métricas
y_pred = (model.predict(X_test) > 0.5).astype("int32")

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.show()

print(classification_report(y_test, y_pred))
# Out:
#           x         y  label
# 0 -0.134747  0.570614      0
# 1 -0.564801  0.583590      0
# 2  0.504559 -0.684201      0
# 3 -0.313099  0.570945      0
# 4  0.127331  0.294184      0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       1000 non-null   float64
#  1   y       1000 non-null   float64
#  2   label   1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB
# None
# Epoch 1/300
# c:\Users\Alvarez\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5263 - loss: 0.6769 - val_accuracy: 0.5850 - val_loss: 0.6663
# Epoch 2/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6938 - loss: 0.6648 - val_accuracy: 0.7150 - val_loss: 0.6554
# Epoch 3/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7262 - loss: 0.6556 - val_accuracy: 0.7050 - val_loss: 0.6443
# Epoch 4/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7125 - loss: 0.6481 - val_accuracy: 0.6900 - val_loss: 0.6363
# Epoch 5/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6662 - loss: 0.6381 - val_accuracy: 0.6750 - val_loss: 0.6273
# Epoch 6/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6662 - loss: 0.6277 - val_accuracy: 0.6050 - val_loss: 0.6160
# Epoch 7/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6275 - loss: 0.6187 - val_accuracy: 0.5900 - val_loss: 0.6052
# Epoch 8/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6538 - loss: 0.6022 - val_accuracy: 0.5950 - val_loss: 0.5927
# Epoch 9/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6175 - loss: 0.5916 - val_accuracy: 0.6100 - val_loss: 0.5837
# Epoch 10/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6000 - loss: 0.5788 - val_accuracy: 0.6200 - val_loss: 0.5737
# Epoch 11/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6625 - loss: 0.5703 - val_accuracy: 0.6250 - val_loss: 0.5635
# Epoch 12/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6413 - loss: 0.5619 - val_accuracy: 0.6100 - val_loss: 0.5550
# Epoch 13/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6413 - loss: 0.5497 - val_accuracy: 0.6800 - val_loss: 0.5480
# Epoch 14/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6675 - loss: 0.5414 - val_accuracy: 0.6800 - val_loss: 0.5386
# Epoch 15/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6975 - loss: 0.5283 - val_accuracy: 0.7000 - val_loss: 0.5327
# Epoch 16/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7050 - loss: 0.5202 - val_accuracy: 0.6750 - val_loss: 0.5231
# Epoch 17/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7013 - loss: 0.5098 - val_accuracy: 0.7200 - val_loss: 0.5195
# Epoch 18/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7237 - loss: 0.5008 - val_accuracy: 0.7100 - val_loss: 0.5119
# Epoch 19/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7287 - loss: 0.4936 - val_accuracy: 0.7200 - val_loss: 0.5051
# Epoch 20/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7412 - loss: 0.4789 - val_accuracy: 0.7150 - val_loss: 0.4972
# Epoch 21/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7350 - loss: 0.4815 - val_accuracy: 0.7200 - val_loss: 0.4868
# Epoch 22/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7475 - loss: 0.4659 - val_accuracy: 0.7250 - val_loss: 0.4698
# Epoch 23/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7575 - loss: 0.4401 - val_accuracy: 0.7250 - val_loss: 0.4538
# Epoch 24/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7625 - loss: 0.4281 - val_accuracy: 0.7200 - val_loss: 0.4347
# Epoch 25/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7700 - loss: 0.4025 - val_accuracy: 0.7300 - val_loss: 0.4134
# Epoch 26/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7763 - loss: 0.3914 - val_accuracy: 0.7400 - val_loss: 0.4021
# Epoch 27/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7763 - loss: 0.3796 - val_accuracy: 0.7400 - val_loss: 0.3930
# Epoch 28/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7950 - loss: 0.3716 - val_accuracy: 0.7350 - val_loss: 0.3789
# Epoch 29/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8025 - loss: 0.3582 - val_accuracy: 0.7500 - val_loss: 0.3695
# Epoch 30/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8037 - loss: 0.3424 - val_accuracy: 0.8150 - val_loss: 0.3529
# Epoch 31/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8413 - loss: 0.3366 - val_accuracy: 0.8400 - val_loss: 0.3403
# Epoch 32/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8512 - loss: 0.3274 - val_accuracy: 0.8150 - val_loss: 0.3310
# Epoch 33/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8637 - loss: 0.3088 - val_accuracy: 0.9300 - val_loss: 0.3121
# Epoch 34/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8888 - loss: 0.2909 - val_accuracy: 0.9450 - val_loss: 0.2901
# Epoch 35/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9150 - loss: 0.2769 - val_accuracy: 0.9050 - val_loss: 0.2769
# Epoch 36/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9112 - loss: 0.2647 - val_accuracy: 0.9900 - val_loss: 0.2634
# Epoch 37/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9300 - loss: 0.2513 - val_accuracy: 0.9850 - val_loss: 0.2298
# Epoch 38/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9475 - loss: 0.2252 - val_accuracy: 0.9600 - val_loss: 0.2148
# Epoch 39/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9525 - loss: 0.2039 - val_accuracy: 0.9950 - val_loss: 0.1859
# Epoch 40/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9712 - loss: 0.1924 - val_accuracy: 0.9750 - val_loss: 0.1752
# Epoch 41/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9700 - loss: 0.1774 - val_accuracy: 0.9950 - val_loss: 0.1491
# Epoch 42/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9850 - loss: 0.1532 - val_accuracy: 0.9950 - val_loss: 0.1324
# Epoch 43/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9887 - loss: 0.1352 - val_accuracy: 1.0000 - val_loss: 0.1174
# Epoch 44/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9762 - loss: 0.1257 - val_accuracy: 1.0000 - val_loss: 0.1018
# Epoch 45/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9825 - loss: 0.1120 - val_accuracy: 0.9950 - val_loss: 0.0978
# Epoch 46/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9862 - loss: 0.1081 - val_accuracy: 0.9950 - val_loss: 0.0876
# Epoch 47/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9862 - loss: 0.0941 - val_accuracy: 1.0000 - val_loss: 0.0722
# Epoch 48/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9950 - loss: 0.0784 - val_accuracy: 1.0000 - val_loss: 0.0628
# Epoch 49/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9900 - loss: 0.0757 - val_accuracy: 1.0000 - val_loss: 0.0635
# Epoch 50/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9887 - loss: 0.0759 - val_accuracy: 1.0000 - val_loss: 0.0541
# Epoch 51/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0607 - val_accuracy: 1.0000 - val_loss: 0.0501
# Epoch 52/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0592 - val_accuracy: 1.0000 - val_loss: 0.0461
# Epoch 53/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9950 - loss: 0.0515 - val_accuracy: 1.0000 - val_loss: 0.0419
# Epoch 54/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9925 - loss: 0.0529 - val_accuracy: 1.0000 - val_loss: 0.0373
# Epoch 55/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9937 - loss: 0.0474 - val_accuracy: 1.0000 - val_loss: 0.0338
# Epoch 56/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9950 - loss: 0.0447 - val_accuracy: 1.0000 - val_loss: 0.0366
# Epoch 57/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0429 - val_accuracy: 1.0000 - val_loss: 0.0270
# Epoch 58/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0392 - val_accuracy: 1.0000 - val_loss: 0.0291
# Epoch 59/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0366 - val_accuracy: 1.0000 - val_loss: 0.0280
# Epoch 60/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 0.0222
# Epoch 61/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0361 - val_accuracy: 0.9950 - val_loss: 0.0282
# Epoch 62/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0373 - val_accuracy: 1.0000 - val_loss: 0.0203
# Epoch 63/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0263 - val_accuracy: 1.0000 - val_loss: 0.0175
# Epoch 64/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 0.0180
# Epoch 65/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 0.0149
# Epoch 66/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 67/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0226 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 68/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0183 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 69/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9950 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 0.0124
# Epoch 70/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0177 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 71/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 72/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 73/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0178 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 74/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 75/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9950 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 76/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 77/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9937 - loss: 0.0176 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 78/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 79/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 80/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 81/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 82/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 83/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 84/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 85/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 86/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 87/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 88/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0164 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 89/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 90/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 91/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 92/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 93/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 94/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 95/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 96/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 97/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 98/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 99/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 100/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 101/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 102/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 103/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 104/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 105/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 106/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 107/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 108/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 109/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 110/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 111/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 112/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 113/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 114/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 115/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 116/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 117/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 118/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 119/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 120/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 121/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 122/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 123/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 124/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 125/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 126/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 127/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 128/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9950 - val_loss: 0.0121
# Epoch 129/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 130/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 131/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 132/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 7.9141e-04
# Epoch 133/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 134/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 135/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 136/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9950 - val_loss: 0.0147
# Epoch 137/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 138/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 139/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 7.8302e-04
# Epoch 140/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 6.5634e-04
# Epoch 141/300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 142/300
#  1/50 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0061
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 52
#      44 model.compile(
#      45     optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),  # LR más bajo
#      46     loss='binary_crossentropy',
#      47     metrics=['accuracy']
#      48 )
#      50 # 4. Entrenar
# ---> 52 history = model.fit(
#      53     X_train, y_train,
#      54     validation_data=(X_test, y_test),
#      55     epochs=300,                # más épocas
#      56     batch_size=16,
#      57     verbose=1
#      58 )
#      60 # Evaluación en test
#      61 loss, acc = model.evaluate(X_test, y_test)
#
# File c:\Users\Alvarez\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Alvarez\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:412, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     391         self._eval_epoch_iterator = TFEpochIterator(
#     392             x=val_x,
#     393             y=val_y,
#    (...)    399             shuffle=False,
#     400         )
#     401     val_logs = self.evaluate(
#     402         x=val_x,
#     403         y=val_y,
#    (...)    409         _use_cached_eval_dataset=True,
#     410     )
#     411     val_logs = {
# --> 412         "val_" + name: val for name, val in val_logs.items()
#     413     }
#     414     epoch_logs.update(val_logs)
#     416 callbacks.on_epoch_end(epoch, epoch_logs)
#
# KeyboardInterrupt:
